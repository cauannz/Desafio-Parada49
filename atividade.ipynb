# %%
musica = "poesia.txt"
cont = 0
vogais = "aeiou"

any = open(musica, "r", encoding="utf-8") 
conteudo = any.read().lower()
palavras = conteudo.split()
for char in conteudo:
        if char in vogais:
            cont += 1

            print(f'Na música "Dialogo" do Yunk Vino, há um total de {cont} vogais.')

            any.close()
# Out:
# Na música "Dialogo" do Yunk Vino, há um total de 1 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 2 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 3 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 4 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 5 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 6 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 7 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 8 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 9 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 10 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 11 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 12 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 13 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 14 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 15 vogais.
# Na música "Dialogo" do Yunk Vino, há um total de 16 vogais.
# ...
